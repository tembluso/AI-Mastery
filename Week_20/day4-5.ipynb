# %% [markdown]
# Week 20 · Days 4–5 — Final Capstone Project (Design & Build)
# Why this matters
#
# This is your moment to synthesize everything you’ve learned — from data prep to ethics, interpretability, and deployment.
# By the end, you’ll have a complete, working AI app that you can show as a portfolio project.
#
# Theory Essentials
#
# Goal: demonstrate end-to-end AI mastery — problem framing → model → interface → ethics.
#
# Key principle: clarity > complexity. Build something you can explain deeply.
#
# Choose one track:
#
# LLM Application — custom assistant or RAG system.
#
# Generative Model — GAN/VAE/Diffusion art app.
#
# RL Agent — simple agent trained in Gym.
#
# Hybrid System — e.g., retrieval + generation (creative AI assistant).
#
# Core structure: data/, model/, app/, README.md, requirements.txt.
#
# Safety requirement: must include one element of interpretability or bias audit.

# %% [markdown]
# 1) Core (15 min)
#
# Task: Pick your project theme and describe it in 3 sentences (problem, data, model).
# Hint: focus on clarity — e.g., “I’ll build a movie review classifier using BERT fine-tuning to detect sentiment in new reviews.”

# %%
Problem: I want to turn my personal notes from books and podcasts into concise, shareable tweets that capture key insights without manually searching through all my material.
Data: Book and Podcast notes
Model: Hybrid AI system that combines RAG using an LLM to generate posts based on retreived content
Goal: Produce accurate drafts within the context specified and mainting certain writing style

# %% [markdown]
# 2) Practice (20–25 min)
#
# Task: Create your project scaffold (folders + base README + requirements + script stubs).

# %% [markdown]
# Mini-Challenge (≤60 min)
#
# Task: Begin implementing your capstone (at least data loading + model training).
# Acceptance Criteria:
# ✅ Working train.py that runs end-to-end on your dataset.
# ✅ Clear README explaining data source, method, metrics, and ethical considerations.
# ✅ Include one responsible AI check (bias report or SHAP plot).
# ✅ Commit all files in a clean, documented folder structure.

# %%
Notes / Key Takeaways

Keep your scope realistic — a finished, explainable project beats an unfinished ambitious one.

Use Week 19’s optimization tricks (AMP, distillation) if relevant.

Responsible AI and interpretability aren’t optional — they’re core quality metrics.

Include visuals: confusion matrix, SHAP summary, or generated samples.

Treat your README as a presentation document — clarity matters.

This is your portfolio anchor — make it reproducible.

# %% [markdown]
# Reflection
#
# What real-world problem inspired your project choice?
#
# How will you ensure your model remains ethical and interpretable after deployment?

# %% [markdown]
# 1.I have a lot of scattered ideas and notes that I can turn into posts but waste a lot of time searching for them.
# 2.Monitoring results and use SHAP of Lime to make the AI decisions transparent.
